# %%
import ngram
import re
from nltk import ngrams

def into_syllable(word, syl_set):
    syllables = []

    bits = ''.join(['1' if l in 'aeiou' else '0' for l in word])

    seperators = (
        ('101', 1),
        ('1001', 2),
        ('10001', 3)
    )

    index, cut_start_pos = 0, 0

    while index < len(bits):

        for seperator_pattern, seperator_cut_pos in seperators:
            if bits[index:].startswith(seperator_pattern):

                syllables.append(word[cut_start_pos:index + seperator_cut_pos])

                index += seperator_cut_pos
                cut_start_pos = index
                break

        index += 1

    syllables.append(word[cut_start_pos:])
    return syllables

def gram1(syl_set,dict_1):
    for syl1 in syl_set:
        for syl2 in syl_set:
            if ngram.NGram.compare(syl1,syl2,N=1) != 0:
                key = syl1+'*'+syl2
                dict_1[key] = ngram.NGram.compare(syl1,syl2,N=1)
                
    for key in dict_1:
        print(key + '\t' + str(dict_1[key]))
            
def gram2(syl_set,dict_2):
    for syl1 in syl_set:
        for syl2 in syl_set:
            for syl3 in syl_set:
                if ngram.NGram.compare(syl1,syl2,syl3,N=2) != 0:
                    key = syl1+'*'+syl2+'*'+syl3
                    dict_2[key] = ngram.NGram.compare(syl1,syl2,syl3,N=2)
                
    for key in dict_2:
        print(key + '\t' + str(dict_2[key]))
        
def gram3(syl_set,dict_3):
    for syl1 in syl_set:
        for syl2 in syl_set:
            for syl3 in syl_set:
                for syl4 in syl_set:
                    if ngram.NGram.compare(syl1,syl2,syl3,syl4,N=3) != 0:
                        key = syl1+'*'+syl2+'*'+syl3+'*'+syl4
                        dict_3[key] = ngram.NGram.compare(syl1,syl2,syl3,syl4,N=3)
                
    for key in dict_3:
        print(key + '\t' + str(dict_3[key]))

def read_file(text):
    syl_set = set([])
    file = open(text, 'r')
    f = file.readlines()
    for line in f:
        for word in re.split('. | ', line):
            for syl in into_syllable(word, syl_set):
                syl_set.add(syl)
                
    print(syl_set)
    
    dict_1 = {}
    dict_2 = {}
    dict_3 = {}
    
    gram1(syl_set,dict_1)
    #gram2(syl_set,dict_2)
    #gram3(syl_set,dict_3)
    
    n_grams = ngrams(syl_set, 1)
    for grams in n_grams:
        print(grams)
        
    n_grams = ngrams(syl_set, 2)
    for grams in n_grams:
        print(grams)
        
    n_grams = ngrams(syl_set, 3)
    for grams in n_grams:
        print(grams)

read_file("wiki_00.txt")
# Out:
# {'122', 'kon', 'da', 'bil', 'se', 'Ta', 'nus', 'ne', 'den', 'ya', 'lind', 'ih', 'hic', 'ta', 'gor', 'du', 'muzd', 'yi', 'i', 'ol', 'gol', 'sind', 'red', 'mak', '6', 'ma', 'pi', 'din', 'lun', 'ru', 'il', 'rin', 'dir', 'ce', 'yok', 'Ha', 'he', 'gund', 'ko', 'Han', '2', 'Ya', 'ke', 'yu', 'ti', "'i", 'ri', 'sap', 'sir', 'sin', 'mall', 'n', 'to', 'na', 'bu', 'Gizl', 'gi', 'Mo', 'ka', 'gil', 'ul', 'hâl', 'b', 'hind', 'lar', 'Cen', 'dug', 'la', 'gu', 'nu', 'Agus', 'tur', 'bi', 'di'}
# 122*122	1.0
# 122*2	0.3333333333333333
# kon*kon	1.0
# kon*nus	0.2
# kon*ne	0.25
# kon*den	0.2
# kon*lind	0.16666666666666666
# kon*gor	0.2
# kon*ol	0.25
# kon*gol	0.2
# kon*sind	0.16666666666666666
# kon*mak	0.2
# kon*din	0.2
# kon*lun	0.2
# kon*rin	0.2
# kon*yok	0.5
# kon*gund	0.16666666666666666
# kon*ko	0.6666666666666666
# kon*Han	0.2
# kon*ke	0.25
# kon*sin	0.2
# kon*n	0.3333333333333333
# kon*to	0.25
# kon*na	0.25
# kon*Mo	0.25
# kon*ka	0.25
# kon*hind	0.16666666666666666
# kon*Cen	0.2
# kon*nu	0.25
# da*da	1.0
# da*Ta	0.3333333333333333
# da*den	0.25
# da*ya	0.3333333333333333
# da*lind	0.2
# da*ta	0.3333333333333333
# da*du	0.3333333333333333
# da*muzd	0.2
# da*sind	0.2
# da*red	0.25
# da*mak	0.25
# da*ma	0.3333333333333333
# da*din	0.25
# da*dir	0.25
# da*Ha	0.3333333333333333
# da*gund	0.2
# da*Han	0.25
# da*Ya	0.3333333333333333
# da*sap	0.25
# da*mall	0.2
# da*na	0.3333333333333333
# da*ka	0.3333333333333333
# da*hind	0.2
# da*lar	0.25
# da*dug	0.25
# da*la	0.3333333333333333
# da*di	0.3333333333333333
# bil*bil	1.0
# bil*lind	0.4
# bil*ih	0.25
# bil*hic	0.2
# bil*yi	0.25
# bil*i	0.3333333333333333
# bil*ol	0.25
# bil*gol	0.2
# bil*sind	0.16666666666666666
# bil*pi	0.25
# bil*din	0.2
# bil*lun	0.2
# bil*il	0.6666666666666666
# bil*rin	0.2
# bil*dir	0.2
# bil*ti	0.25
# bil*'i	0.25
# bil*ri	0.25
# bil*sir	0.2
# bil*sin	0.2
# bil*mall	0.16666666666666666
# bil*bu	0.25
# bil*Gizl	0.4
# bil*gi	0.25
# bil*gil	0.5
# bil*ul	0.25
# bil*hâl	0.2
# bil*b	0.3333333333333333
# bil*hind	0.16666666666666666
# bil*lar	0.2
# bil*la	0.25
# bil*bi	0.6666666666666666
# bil*di	0.25
# se*se	1.0
# se*nus	0.25
# se*ne	0.3333333333333333
# se*den	0.25
# se*sind	0.2
# se*red	0.25
# se*ce	0.3333333333333333
# se*he	0.3333333333333333
# se*ke	0.3333333333333333
# se*sap	0.25
# se*sir	0.25
# se*sin	0.25
# se*Cen	0.25
# se*Agus	0.2
# Ta*da	0.3333333333333333
# Ta*Ta	1.0
# Ta*ya	0.3333333333333333
# Ta*ta	0.3333333333333333
# Ta*mak	0.25
# Ta*ma	0.3333333333333333
# Ta*Ha	0.3333333333333333
# Ta*Han	0.25
# Ta*Ya	0.3333333333333333
# Ta*sap	0.25
# Ta*mall	0.2
# Ta*na	0.3333333333333333
# Ta*ka	0.3333333333333333
# Ta*lar	0.25
# Ta*la	0.3333333333333333
# nus*kon	0.2
# nus*se	0.25
# nus*nus	1.0
# nus*ne	0.25
# nus*den	0.2
# nus*lind	0.16666666666666666
# nus*du	0.25
# nus*muzd	0.16666666666666666
# nus*sind	0.4
# nus*din	0.2
# nus*lun	0.5
# nus*ru	0.25
# nus*rin	0.2
# nus*gund	0.4
# nus*Han	0.2
# nus*yu	0.25
# nus*sap	0.2
# nus*sir	0.2
# nus*sin	0.5
# nus*n	0.3333333333333333
# nus*na	0.25
# nus*bu	0.25
# nus*ul	0.25
# nus*hind	0.16666666666666666
# nus*Cen	0.2
# nus*dug	0.2
# nus*gu	0.25
# nus*nu	0.6666666666666666
# nus*Agus	0.4
# nus*tur	0.2
# ne*kon	0.25
# ne*se	0.3333333333333333
# ne*nus	0.25
# ne*ne	1.0
# ne*den	0.6666666666666666
# ne*lind	0.2
# ne*sind	0.2
# ne*red	0.25
# ne*din	0.25
# ne*lun	0.25
# ne*rin	0.25
# ne*ce	0.3333333333333333
# ne*he	0.3333333333333333
# ne*gund	0.2
# ne*Han	0.25
# ne*ke	0.3333333333333333
# ne*sin	0.25
# ne*n	0.5
# ne*na	0.3333333333333333
# ne*hind	0.2
# ne*Cen	0.6666666666666666
# ne*nu	0.3333333333333333
# den*kon	0.2
# den*da	0.25
# den*se	0.25
# den*nus	0.2
# den*ne	0.6666666666666666
# den*den	1.0
# den*lind	0.4
# den*du	0.25
# den*muzd	0.16666666666666666
# den*sind	0.4
# den*red	0.5
# den*din	0.5
# den*lun	0.2
# den*rin	0.2
# den*dir	0.2
# den*ce	0.25
# den*he	0.25
# den*gund	0.4
# den*Han	0.2
# den*ke	0.25
# den*sin	0.2
# den*n	0.3333333333333333
# den*na	0.25
# den*hind	0.4
# den*Cen	0.5
# den*dug	0.2
# den*nu	0.25
# den*di	0.25
# ya*da	0.3333333333333333
# ya*Ta	0.3333333333333333
# ya*ya	1.0
# ya*ta	0.3333333333333333
# ya*yi	0.3333333333333333
# ya*mak	0.25
# ya*ma	0.3333333333333333
# ya*yok	0.25
# ya*Ha	0.3333333333333333
# ya*Han	0.25
# ya*Ya	0.3333333333333333
# ya*yu	0.3333333333333333
# ya*sap	0.25
# ya*mall	0.2
# ya*na	0.3333333333333333
# ya*ka	0.3333333333333333
# ya*lar	0.25
# ya*la	0.3333333333333333
# lind*kon	0.16666666666666666
# lind*da	0.2
# lind*bil	0.4
# lind*nus	0.16666666666666666
# lind*ne	0.2
# lind*den	0.4
# lind*lind	1.0
# lind*ih	0.2
# lind*hic	0.16666666666666666
# lind*du	0.2
# lind*muzd	0.14285714285714285
# lind*yi	0.2
# lind*i	0.25
# lind*ol	0.2
# lind*gol	0.16666666666666666
# lind*sind	0.6
# lind*red	0.16666666666666666
# lind*pi	0.2
# lind*din	0.75
# lind*lun	0.4
# lind*il	0.5
# lind*rin	0.4
# lind*dir	0.4
# lind*gund	0.3333333333333333
# lind*Han	0.16666666666666666
# lind*ti	0.2
# lind*'i	0.2
# lind*ri	0.2
# lind*sir	0.16666666666666666
# lind*sin	0.4
# lind*mall	0.14285714285714285
# lind*n	0.25
# lind*na	0.2
# lind*Gizl	0.3333333333333333
# lind*gi	0.2
# lind*gil	0.4
# lind*ul	0.2
# lind*hâl	0.16666666666666666
# lind*hind	0.6
# lind*lar	0.16666666666666666
# lind*Cen	0.16666666666666666
# lind*dug	0.16666666666666666
# lind*la	0.2
# lind*nu	0.2
# lind*bi	0.2
# lind*di	0.5
# ih*bil	0.25
# ih*lind	0.2
# ih*ih	1.0
# ih*hic	0.6666666666666666
# ih*yi	0.3333333333333333
# ih*i	0.5
# ih*sind	0.2
# ih*pi	0.3333333333333333
# ih*din	0.25
# ih*il	0.3333333333333333
# ih*rin	0.25
# ih*dir	0.25
# ih*he	0.3333333333333333
# ih*ti	0.3333333333333333
# ih*'i	0.3333333333333333
# ih*ri	0.3333333333333333
# ih*sir	0.25
# ih*sin	0.25
# ih*Gizl	0.2
# ih*gi	0.3333333333333333
# ih*gil	0.25
# ih*hâl	0.25
# ih*hind	0.5
# ih*bi	0.3333333333333333
# ih*di	0.3333333333333333
# hic*bil	0.2
# hic*lind	0.16666666666666666
# hic*ih	0.6666666666666666
# hic*hic	1.0
# hic*yi	0.25
# hic*i	0.3333333333333333
# hic*sind	0.16666666666666666
# hic*pi	0.25
# hic*din	0.2
# hic*il	0.25
# hic*rin	0.2
# hic*dir	0.2
# hic*ce	0.25
# hic*he	0.25
# hic*ti	0.25
# hic*'i	0.25
# hic*ri	0.25
# hic*sir	0.2
# hic*sin	0.2
# hic*Gizl	0.16666666666666666
# hic*gi	0.25
# hic*gil	0.2
# hic*hâl	0.2
# hic*hind	0.4
# hic*bi	0.25
# hic*di	0.25
# ta*da	0.3333333333333333
# ta*Ta	0.3333333333333333
# ta*ya	0.3333333333333333
# ta*ta	1.0
# ta*mak	0.25
# ta*ma	0.3333333333333333
# ta*Ha	0.3333333333333333
# ta*Han	0.25
# ta*Ya	0.3333333333333333
# ta*ti	0.3333333333333333
# ta*sap	0.25
# ta*mall	0.2
# ta*to	0.3333333333333333
# ta*na	0.3333333333333333
# ta*ka	0.3333333333333333
# ta*lar	0.25
# ta*la	0.3333333333333333
# ta*tur	0.25
# gor*kon	0.2
# gor*gor	1.0
# gor*ol	0.25
# gor*gol	0.5
# gor*red	0.2
# gor*ru	0.25
# gor*rin	0.2
# gor*dir	0.2
# gor*yok	0.2
# gor*gund	0.16666666666666666
# gor*ko	0.25
# gor*ri	0.25
# gor*sir	0.2
# gor*to	0.25
# gor*gi	0.25
# gor*Mo	0.25
# gor*gil	0.2
# gor*lar	0.2
# gor*dug	0.2
# gor*gu	0.25
# gor*Agus	0.16666666666666666
# gor*tur	0.2
# du*da	0.3333333333333333
# du*nus	0.25
# du*den	0.25
# du*lind	0.2
# du*du	1.0
# du*muzd	0.5
# du*sind	0.2
# du*red	0.25
# du*din	0.25
# du*lun	0.25
# du*ru	0.3333333333333333
# du*dir	0.25
# du*gund	0.5
# du*yu	0.3333333333333333
# du*bu	0.3333333333333333
# du*ul	0.3333333333333333
# du*hind	0.2
# du*dug	0.6666666666666666
# du*gu	0.3333333333333333
# du*nu	0.3333333333333333
# du*Agus	0.2
# du*tur	0.25
# du*di	0.3333333333333333
# muzd*da	0.2
# muzd*nus	0.16666666666666666
# muzd*den	0.16666666666666666
# muzd*lind	0.14285714285714285
# muzd*du	0.5
# muzd*muzd	1.0
# muzd*sind	0.14285714285714285
# muzd*red	0.16666666666666666
# muzd*mak	0.16666666666666666
# muzd*ma	0.2
# muzd*din	0.16666666666666666
# muzd*lun	0.16666666666666666
# muzd*ru	0.2
# muzd*dir	0.16666666666666666
# muzd*gund	0.3333333333333333
# muzd*yu	0.2
# muzd*mall	0.14285714285714285
# muzd*bu	0.2
# muzd*Gizl	0.14285714285714285
# muzd*ul	0.2
# muzd*hind	0.14285714285714285
# muzd*dug	0.4
# muzd*gu	0.2
# muzd*nu	0.2
# muzd*Agus	0.14285714285714285
# muzd*tur	0.16666666666666666
# muzd*di	0.2
# yi*bil	0.25
# yi*ya	0.3333333333333333
# yi*lind	0.2
# yi*ih	0.3333333333333333
# yi*hic	0.25
# yi*yi	1.0
# yi*i	0.5
# yi*sind	0.2
# yi*pi	0.3333333333333333
# yi*din	0.25
# yi*il	0.3333333333333333
# yi*rin	0.25
# yi*dir	0.25
# yi*yok	0.25
# yi*yu	0.3333333333333333
# yi*ti	0.3333333333333333
# yi*'i	0.3333333333333333
# yi*ri	0.3333333333333333
# yi*sir	0.25
# yi*sin	0.25
# yi*Gizl	0.2
# yi*gi	0.3333333333333333
# yi*gil	0.25
# yi*hind	0.2
# yi*bi	0.3333333333333333
# yi*di	0.3333333333333333
# i*bil	0.3333333333333333
# i*lind	0.25
# i*ih	0.5
# i*hic	0.3333333333333333
# i*yi	0.5
# i*i	1.0
# i*sind	0.25
# i*pi	0.5
# i*din	0.3333333333333333
# i*il	0.5
# i*rin	0.3333333333333333
# i*dir	0.3333333333333333
# i*ti	0.5
# i*'i	0.5
# i*ri	0.5
# i*sir	0.3333333333333333
# i*sin	0.3333333333333333
# i*Gizl	0.25
# i*gi	0.5
# i*gil	0.3333333333333333
# i*hind	0.25
# i*bi	0.5
# i*di	0.5
# ol*kon	0.25
# ol*bil	0.25
# ol*lind	0.2
# ol*gor	0.25
# ol*ol	1.0
# ol*gol	0.6666666666666666
# ol*lun	0.25
# ol*il	0.3333333333333333
# ol*yok	0.25
# ol*ko	0.3333333333333333
# ol*mall	0.2
# ol*to	0.3333333333333333
# ol*Gizl	0.2
# ol*Mo	0.3333333333333333
# ol*gil	0.25
# ol*ul	0.3333333333333333
# ol*hâl	0.25
# ol*lar	0.25
# ol*la	0.3333333333333333
# gol*kon	0.2
# gol*bil	0.2
# gol*lind	0.16666666666666666
# gol*gor	0.5
# gol*ol	0.6666666666666666
# gol*gol	1.0
# gol*lun	0.2
# gol*il	0.25
# gol*yok	0.2
# gol*gund	0.16666666666666666
# gol*ko	0.25
# gol*mall	0.16666666666666666
# gol*to	0.25
# gol*Gizl	0.16666666666666666
# gol*gi	0.25
# gol*Mo	0.25
# gol*gil	0.5
# gol*ul	0.25
# gol*hâl	0.2
# gol*lar	0.2
# gol*dug	0.2
# gol*la	0.25
# gol*gu	0.25
# gol*Agus	0.16666666666666666
# sind*kon	0.16666666666666666
# sind*da	0.2
# sind*bil	0.16666666666666666
# sind*se	0.2
# sind*nus	0.4
# sind*ne	0.2
# sind*den	0.4
# sind*lind	0.6
# sind*ih	0.2
# sind*hic	0.16666666666666666
# sind*du	0.2
# sind*muzd	0.14285714285714285
# sind*yi	0.2
# sind*i	0.25
# sind*sind	1.0
# sind*red	0.16666666666666666
# sind*pi	0.2
# sind*din	0.75
# sind*lun	0.16666666666666666
# sind*il	0.2
# sind*rin	0.4
# sind*dir	0.4
# sind*gund	0.3333333333333333
# sind*Han	0.16666666666666666
# sind*ti	0.2
# sind*'i	0.2
# sind*ri	0.2
# sind*sap	0.16666666666666666
# sind*sir	0.4
# sind*sin	0.75
# sind*n	0.25
# sind*na	0.2
# sind*Gizl	0.14285714285714285
# sind*gi	0.2
# sind*gil	0.16666666666666666
# sind*hind	0.6
# sind*Cen	0.16666666666666666
# sind*dug	0.16666666666666666
# sind*nu	0.2
# sind*Agus	0.14285714285714285
# sind*bi	0.2
# sind*di	0.5
# red*da	0.25
# red*se	0.25
# red*ne	0.25
# red*den	0.5
# red*lind	0.16666666666666666
# red*gor	0.2
# red*du	0.25
# red*muzd	0.16666666666666666
# red*sind	0.16666666666666666
# red*red	1.0
# red*din	0.2
# red*ru	0.25
# red*rin	0.2
# red*dir	0.5
# red*ce	0.25
# red*he	0.25
# red*gund	0.16666666666666666
# red*ke	0.25
# red*ri	0.25
# red*sir	0.2
# red*hind	0.16666666666666666
# red*lar	0.2
# red*Cen	0.2
# red*dug	0.2
# red*tur	0.2
# red*di	0.25
# mak*kon	0.2
# mak*da	0.25
# mak*Ta	0.25
# mak*ya	0.25
# mak*ta	0.25
# mak*muzd	0.16666666666666666
# mak*mak	1.0
# mak*ma	0.6666666666666666
# mak*yok	0.2
# mak*Ha	0.25
# mak*ko	0.25
# mak*Han	0.2
# mak*Ya	0.25
# mak*ke	0.25
# mak*sap	0.2
# mak*mall	0.4
# mak*na	0.25
# mak*ka	0.6666666666666666
# mak*lar	0.2
# mak*la	0.25
# 6*6	1.0
# ma*da	0.3333333333333333
# ma*Ta	0.3333333333333333
# ma*ya	0.3333333333333333
# ma*ta	0.3333333333333333
# ma*muzd	0.2
# ma*mak	0.6666666666666666
# ma*ma	1.0
# ma*Ha	0.3333333333333333
# ma*Han	0.25
# ma*Ya	0.3333333333333333
# ma*sap	0.25
# ma*mall	0.5
# ma*na	0.3333333333333333
# ma*ka	0.3333333333333333
# ma*lar	0.25
# ma*la	0.3333333333333333
# pi*bil	0.25
# pi*lind	0.2
# pi*ih	0.3333333333333333
# pi*hic	0.25
# pi*yi	0.3333333333333333
# pi*i	0.5
# pi*sind	0.2
# pi*pi	1.0
# pi*din	0.25
# pi*il	0.3333333333333333
# pi*rin	0.25
# pi*dir	0.25
# pi*ti	0.3333333333333333
# pi*'i	0.3333333333333333
# pi*ri	0.3333333333333333
# pi*sap	0.25
# pi*sir	0.25
# pi*sin	0.25
# pi*Gizl	0.2
# pi*gi	0.3333333333333333
# pi*gil	0.25
# pi*hind	0.2
# pi*bi	0.3333333333333333
# pi*di	0.3333333333333333
# din*kon	0.2
# din*da	0.25
# din*bil	0.2
# din*nus	0.2
# din*ne	0.25
# din*den	0.5
# din*lind	0.75
# din*ih	0.25
# din*hic	0.2
# din*du	0.25
# din*muzd	0.16666666666666666
# din*yi	0.25
# din*i	0.3333333333333333
# din*sind	0.75
# din*red	0.2
# din*pi	0.25
# din*din	1.0
# din*lun	0.2
# din*il	0.25
# din*rin	0.5
# din*dir	0.5
# din*gund	0.4
# din*Han	0.2
# din*ti	0.25
# din*'i	0.25
# din*ri	0.25
# din*sir	0.2
# din*sin	0.5
# din*n	0.3333333333333333
# din*na	0.25
# din*Gizl	0.16666666666666666
# din*gi	0.25
# din*gil	0.2
# din*hind	0.75
# din*Cen	0.2
# din*dug	0.2
# din*nu	0.25
# din*bi	0.25
# din*di	0.6666666666666666
# lun*kon	0.2
# lun*bil	0.2
# lun*nus	0.5
# lun*ne	0.25
# lun*den	0.2
# lun*lind	0.4
# lun*du	0.25
# lun*muzd	0.16666666666666666
# lun*ol	0.25
# lun*gol	0.2
# lun*sind	0.16666666666666666
# lun*din	0.2
# lun*lun	1.0
# lun*ru	0.25
# lun*il	0.25
# lun*rin	0.2
# lun*gund	0.4
# lun*Han	0.2
# lun*yu	0.25
# lun*sin	0.2
# lun*mall	0.16666666666666666
# lun*n	0.3333333333333333
# lun*na	0.25
# lun*bu	0.25
# lun*Gizl	0.16666666666666666
# lun*gil	0.2
# lun*ul	0.6666666666666666
# lun*hâl	0.2
# lun*hind	0.16666666666666666
# lun*lar	0.2
# lun*Cen	0.2
# lun*dug	0.2
# lun*la	0.25
# lun*gu	0.25
# lun*nu	0.6666666666666666
# lun*Agus	0.16666666666666666
# lun*tur	0.2
# ru*nus	0.25
# ru*gor	0.25
# ru*du	0.3333333333333333
# ru*muzd	0.2
# ru*red	0.25
# ru*lun	0.25
# ru*ru	1.0
# ru*rin	0.25
# ru*dir	0.25
# ru*gund	0.2
# ru*yu	0.3333333333333333
# ru*ri	0.3333333333333333
# ru*sir	0.25
# ru*bu	0.3333333333333333
# ru*ul	0.3333333333333333
# ru*lar	0.25
# ru*dug	0.25
# ru*gu	0.3333333333333333
# ru*nu	0.3333333333333333
# ru*Agus	0.2
# ru*tur	0.6666666666666666
# il*bil	0.6666666666666666
# il*lind	0.5
# il*ih	0.3333333333333333
# il*hic	0.25
# il*yi	0.3333333333333333
# il*i	0.5
# il*ol	0.3333333333333333
# il*gol	0.25
# il*sind	0.2
# il*pi	0.3333333333333333
# il*din	0.25
# il*lun	0.25
# il*il	1.0
# il*rin	0.25
# il*dir	0.25
# il*ti	0.3333333333333333
# il*'i	0.3333333333333333
# il*ri	0.3333333333333333
# il*sir	0.25
# il*sin	0.25
# il*mall	0.2
# il*Gizl	0.5
# il*gi	0.3333333333333333
# il*gil	0.6666666666666666
# il*ul	0.3333333333333333
# il*hâl	0.25
# il*hind	0.2
# il*lar	0.25
# il*la	0.3333333333333333
# il*bi	0.3333333333333333
# il*di	0.3333333333333333
# rin*kon	0.2
# rin*bil	0.2
# rin*nus	0.2
# rin*ne	0.25
# rin*den	0.2
# rin*lind	0.4
# rin*ih	0.25
# rin*hic	0.2
# rin*gor	0.2
# rin*yi	0.25
# rin*i	0.3333333333333333
# rin*sind	0.4
# rin*red	0.2
# rin*pi	0.25
# rin*din	0.5
# rin*lun	0.2
# rin*ru	0.25
# rin*il	0.25
# rin*rin	1.0
# rin*dir	0.5
# rin*gund	0.16666666666666666
# rin*Han	0.2
# rin*ti	0.25
# rin*'i	0.25
# rin*ri	0.6666666666666666
# rin*sir	0.5
# rin*sin	0.5
# rin*n	0.3333333333333333
# rin*na	0.25
# rin*Gizl	0.16666666666666666
# rin*gi	0.25
# rin*gil	0.2
# rin*hind	0.4
# rin*lar	0.2
# rin*Cen	0.2
# rin*nu	0.25
# rin*tur	0.2
# rin*bi	0.25
# rin*di	0.25
# dir*da	0.25
# dir*bil	0.2
# dir*den	0.2
# dir*lind	0.4
# dir*ih	0.25
# dir*hic	0.2
# dir*gor	0.2
# dir*du	0.25
# dir*muzd	0.16666666666666666
# dir*yi	0.25
# dir*i	0.3333333333333333
# dir*sind	0.4
# dir*red	0.5
# dir*pi	0.25
# dir*din	0.5
# dir*ru	0.25
# dir*il	0.25
# dir*rin	0.5
# dir*dir	1.0
# dir*gund	0.16666666666666666
# dir*ti	0.25
# dir*'i	0.25
# dir*ri	0.6666666666666666
# dir*sir	0.5
# dir*sin	0.2
# dir*Gizl	0.16666666666666666
# dir*gi	0.25
# dir*gil	0.2
# dir*hind	0.4
# dir*lar	0.2
# dir*dug	0.2
# dir*tur	0.2
# dir*bi	0.25
# dir*di	0.6666666666666666
# ce*se	0.3333333333333333
# ce*ne	0.3333333333333333
# ce*den	0.25
# ce*hic	0.25
# ce*red	0.25
# ce*ce	1.0
# ce*he	0.3333333333333333
# ce*ke	0.3333333333333333
# ce*Cen	0.25
# yok*kon	0.5
# yok*ya	0.25
# yok*gor	0.2
# yok*yi	0.25
# yok*ol	0.25
# yok*gol	0.2
# yok*mak	0.2
# yok*yok	1.0
# yok*ko	0.6666666666666666
# yok*ke	0.25
# yok*yu	0.25
# yok*to	0.25
# yok*Mo	0.25
# yok*ka	0.25
# Ha*da	0.3333333333333333
# Ha*Ta	0.3333333333333333
# Ha*ya	0.3333333333333333
# Ha*ta	0.3333333333333333
# Ha*mak	0.25
# Ha*ma	0.3333333333333333
# Ha*Ha	1.0
# Ha*Han	0.6666666666666666
# Ha*Ya	0.3333333333333333
# Ha*sap	0.25
# Ha*mall	0.2
# Ha*na	0.3333333333333333
# Ha*ka	0.3333333333333333
# Ha*lar	0.25
# Ha*la	0.3333333333333333
# he*se	0.3333333333333333
# he*ne	0.3333333333333333
# he*den	0.25
# he*ih	0.3333333333333333
# he*hic	0.25
# he*red	0.25
# he*ce	0.3333333333333333
# he*he	1.0
# he*ke	0.3333333333333333
# he*hâl	0.25
# he*hind	0.2
# he*Cen	0.25
# gund*kon	0.16666666666666666
# gund*da	0.2
# gund*nus	0.4
# gund*ne	0.2
# gund*den	0.4
# gund*lind	0.3333333333333333
# gund*gor	0.16666666666666666
# gund*du	0.5
# gund*muzd	0.3333333333333333
# gund*gol	0.16666666666666666
# gund*sind	0.3333333333333333
# gund*red	0.16666666666666666
# gund*din	0.4
# gund*lun	0.4
# gund*ru	0.2
# gund*rin	0.16666666666666666
# gund*dir	0.16666666666666666
# gund*gund	1.0
# gund*Han	0.16666666666666666
# gund*yu	0.2
# gund*sin	0.16666666666666666
# gund*n	0.25
# gund*na	0.2
# gund*bu	0.2
# gund*gi	0.2
# gund*gil	0.16666666666666666
# gund*ul	0.2
# gund*hind	0.3333333333333333
# gund*Cen	0.16666666666666666
# gund*dug	0.75
# gund*gu	0.5
# gund*nu	0.5
# gund*Agus	0.3333333333333333
# gund*tur	0.16666666666666666
# gund*di	0.2
# ko*kon	0.6666666666666666
# ko*gor	0.25
# ko*ol	0.3333333333333333
# ko*gol	0.25
# ko*mak	0.25
# ko*yok	0.6666666666666666
# ko*ko	1.0
# ko*ke	0.3333333333333333
# ko*to	0.3333333333333333
# ko*Mo	0.3333333333333333
# ko*ka	0.3333333333333333
# Han*kon	0.2
# Han*da	0.25
# Han*Ta	0.25
# Han*nus	0.2
# Han*ne	0.25
# Han*den	0.2
# Han*ya	0.25
# Han*lind	0.16666666666666666
# Han*ta	0.25
# Han*sind	0.16666666666666666
# Han*mak	0.2
# Han*ma	0.25
# Han*din	0.2
# Han*lun	0.2
# Han*rin	0.2
# Han*Ha	0.6666666666666666
# Han*gund	0.16666666666666666
# Han*Han	1.0
# Han*Ya	0.25
# Han*sap	0.2
# Han*sin	0.2
# Han*mall	0.16666666666666666
# Han*n	0.3333333333333333
# Han*na	0.6666666666666666
# Han*ka	0.25
# Han*hind	0.16666666666666666
# Han*lar	0.2
# Han*Cen	0.2
# Han*la	0.25
# Han*nu	0.25
# 2*122	0.3333333333333333
# 2*2	1.0
# Ya*da	0.3333333333333333
# Ya*Ta	0.3333333333333333
# Ya*ya	0.3333333333333333
# Ya*ta	0.3333333333333333
# Ya*mak	0.25
# Ya*ma	0.3333333333333333
# Ya*Ha	0.3333333333333333
# Ya*Han	0.25
# Ya*Ya	1.0
# Ya*sap	0.25
# Ya*mall	0.2
# Ya*na	0.3333333333333333
# Ya*ka	0.3333333333333333
# Ya*lar	0.25
# Ya*la	0.3333333333333333
# ke*kon	0.25
# ke*se	0.3333333333333333
# ke*ne	0.3333333333333333
# ke*den	0.25
# ke*red	0.25
# ke*mak	0.25
# ke*ce	0.3333333333333333
# ke*yok	0.25
# ke*he	0.3333333333333333
# ke*ko	0.3333333333333333
# ke*ke	1.0
# ke*ka	0.3333333333333333
# ke*Cen	0.25
# yu*nus	0.25
# yu*ya	0.3333333333333333
# yu*du	0.3333333333333333
# yu*muzd	0.2
# yu*yi	0.3333333333333333
# yu*lun	0.25
# yu*ru	0.3333333333333333
# yu*yok	0.25
# yu*gund	0.2
# yu*yu	1.0
# yu*bu	0.3333333333333333
# yu*ul	0.3333333333333333
# yu*dug	0.25
# yu*gu	0.3333333333333333
# yu*nu	0.3333333333333333
# yu*Agus	0.2
# yu*tur	0.25
# ti*bil	0.25
# ti*lind	0.2
# ti*ih	0.3333333333333333
# ti*hic	0.25
# ti*ta	0.3333333333333333
# ti*yi	0.3333333333333333
# ti*i	0.5
# ti*sind	0.2
# ti*pi	0.3333333333333333
# ti*din	0.25
# ti*il	0.3333333333333333
# ti*rin	0.25
# ti*dir	0.25
# ti*ti	1.0
# ti*'i	0.3333333333333333
# ti*ri	0.3333333333333333
# ti*sir	0.25
# ti*sin	0.25
# ti*to	0.3333333333333333
# ti*Gizl	0.2
# ti*gi	0.3333333333333333
# ti*gil	0.25
# ti*hind	0.2
# ti*tur	0.25
# ti*bi	0.3333333333333333
# ti*di	0.3333333333333333
# 'i*bil	0.25
# 'i*lind	0.2
# 'i*ih	0.3333333333333333
# 'i*hic	0.25
# 'i*yi	0.3333333333333333
# 'i*i	0.5
# 'i*sind	0.2
# 'i*pi	0.3333333333333333
# 'i*din	0.25
# 'i*il	0.3333333333333333
# 'i*rin	0.25
# 'i*dir	0.25
# 'i*ti	0.3333333333333333
# 'i*'i	1.0
# 'i*ri	0.3333333333333333
# 'i*sir	0.25
# 'i*sin	0.25
# 'i*Gizl	0.2
# 'i*gi	0.3333333333333333
# 'i*gil	0.25
# 'i*hind	0.2
# 'i*bi	0.3333333333333333
# 'i*di	0.3333333333333333
# ri*bil	0.25
# ri*lind	0.2
# ri*ih	0.3333333333333333
# ri*hic	0.25
# ri*gor	0.25
# ri*yi	0.3333333333333333
# ri*i	0.5
# ri*sind	0.2
# ri*red	0.25
# ri*pi	0.3333333333333333
# ri*din	0.25
# ri*ru	0.3333333333333333
# ri*il	0.3333333333333333
# ri*rin	0.6666666666666666
# ri*dir	0.6666666666666666
# ri*ti	0.3333333333333333
# ri*'i	0.3333333333333333
# ri*ri	1.0
# ri*sir	0.6666666666666666
# ri*sin	0.25
# ri*Gizl	0.2
# ri*gi	0.3333333333333333
# ri*gil	0.25
# ri*hind	0.2
# ri*lar	0.25
# ri*tur	0.25
# ri*bi	0.3333333333333333
# ri*di	0.3333333333333333
# sap*da	0.25
# sap*se	0.25
# sap*Ta	0.25
# sap*nus	0.2
# sap*ya	0.25
# sap*ta	0.25
# sap*sind	0.16666666666666666
# sap*mak	0.2
# sap*ma	0.25
# sap*pi	0.25
# sap*Ha	0.25
# sap*Han	0.2
# sap*Ya	0.25
# sap*sap	1.0
# sap*sir	0.2
# sap*sin	0.2
# sap*mall	0.16666666666666666
# sap*na	0.25
# sap*ka	0.25
# sap*lar	0.2
# sap*la	0.25
# sap*Agus	0.16666666666666666
# sir*bil	0.2
# sir*se	0.25
# sir*nus	0.2
# sir*lind	0.16666666666666666
# sir*ih	0.25
# sir*hic	0.2
# sir*gor	0.2
# sir*yi	0.25
# sir*i	0.3333333333333333
# sir*sind	0.4
# sir*red	0.2
# sir*pi	0.25
# sir*din	0.2
# sir*ru	0.25
# sir*il	0.25
# sir*rin	0.5
# sir*dir	0.5
# sir*ti	0.25
# sir*'i	0.25
# sir*ri	0.6666666666666666
# sir*sap	0.2
# sir*sir	1.0
# sir*sin	0.5
# sir*Gizl	0.16666666666666666
# sir*gi	0.25
# sir*gil	0.2
# sir*hind	0.16666666666666666
# sir*lar	0.2
# sir*Agus	0.16666666666666666
# sir*tur	0.2
# sir*bi	0.25
# sir*di	0.25
# sin*kon	0.2
# sin*bil	0.2
# sin*se	0.25
# sin*nus	0.5
# sin*ne	0.25
# sin*den	0.2
# sin*lind	0.4
# sin*ih	0.25
# sin*hic	0.2
# sin*yi	0.25
# sin*i	0.3333333333333333
# sin*sind	0.75
# sin*pi	0.25
# sin*din	0.5
# sin*lun	0.2
# sin*il	0.25
# sin*rin	0.5
# sin*dir	0.2
# sin*gund	0.16666666666666666
# sin*Han	0.2
# sin*ti	0.25
# sin*'i	0.25
# sin*ri	0.25
# sin*sap	0.2
# sin*sir	0.5
# sin*sin	1.0
# sin*n	0.3333333333333333
# sin*na	0.25
# sin*Gizl	0.16666666666666666
# sin*gi	0.25
# sin*gil	0.2
# sin*hind	0.4
# sin*Cen	0.2
# sin*nu	0.25
# sin*Agus	0.16666666666666666
# sin*bi	0.25
# sin*di	0.25
# mall*da	0.2
# mall*bil	0.16666666666666666
# mall*Ta	0.2
# mall*ya	0.2
# mall*lind	0.14285714285714285
# mall*ta	0.2
# mall*muzd	0.14285714285714285
# mall*ol	0.2
# mall*gol	0.16666666666666666
# mall*mak	0.4
# mall*ma	0.5
# mall*lun	0.16666666666666666
# mall*il	0.2
# mall*Ha	0.2
# mall*Han	0.16666666666666666
# mall*Ya	0.2
# mall*sap	0.16666666666666666
# mall*mall	1.0
# mall*na	0.2
# mall*Gizl	0.14285714285714285
# mall*ka	0.2
# mall*gil	0.16666666666666666
# mall*ul	0.2
# mall*hâl	0.16666666666666666
# mall*lar	0.4
# mall*la	0.5
# n*kon	0.3333333333333333
# n*nus	0.3333333333333333
# n*ne	0.5
# n*den	0.3333333333333333
# n*lind	0.25
# n*sind	0.25
# n*din	0.3333333333333333
# n*lun	0.3333333333333333
# n*rin	0.3333333333333333
# n*gund	0.25
# n*Han	0.3333333333333333
# n*sin	0.3333333333333333
# n*n	1.0
# n*na	0.5
# n*hind	0.25
# n*Cen	0.3333333333333333
# n*nu	0.5
# to*kon	0.25
# to*ta	0.3333333333333333
# to*gor	0.25
# to*ol	0.3333333333333333
# to*gol	0.25
# to*yok	0.25
# to*ko	0.3333333333333333
# to*ti	0.3333333333333333
# to*to	1.0
# to*Mo	0.3333333333333333
# to*tur	0.25
# na*kon	0.25
# na*da	0.3333333333333333
# na*Ta	0.3333333333333333
# na*nus	0.25
# na*ne	0.3333333333333333
# na*den	0.25
# na*ya	0.3333333333333333
# na*lind	0.2
# na*ta	0.3333333333333333
# na*sind	0.2
# na*mak	0.25
# na*ma	0.3333333333333333
# na*din	0.25
# na*lun	0.25
# na*rin	0.25
# na*Ha	0.3333333333333333
# na*gund	0.2
# na*Han	0.6666666666666666
# na*Ya	0.3333333333333333
# na*sap	0.25
# na*sin	0.25
# na*mall	0.2
# na*n	0.5
# na*na	1.0
# na*ka	0.3333333333333333
# na*hind	0.2
# na*lar	0.25
# na*Cen	0.25
# na*la	0.3333333333333333
# na*nu	0.3333333333333333
# bu*bil	0.25
# bu*nus	0.25
# bu*du	0.3333333333333333
# bu*muzd	0.2
# bu*lun	0.25
# bu*ru	0.3333333333333333
# bu*gund	0.2
# bu*yu	0.3333333333333333
# bu*bu	1.0
# bu*ul	0.3333333333333333
# bu*b	0.5
# bu*dug	0.25
# bu*gu	0.3333333333333333
# bu*nu	0.3333333333333333
# bu*Agus	0.2
# bu*tur	0.25
# bu*bi	0.3333333333333333
# Gizl*bil	0.4
# Gizl*lind	0.3333333333333333
# Gizl*ih	0.2
# Gizl*hic	0.16666666666666666
# Gizl*muzd	0.14285714285714285
# Gizl*yi	0.2
# Gizl*i	0.25
# Gizl*ol	0.2
# Gizl*gol	0.16666666666666666
# Gizl*sind	0.14285714285714285
# Gizl*pi	0.2
# Gizl*din	0.16666666666666666
# Gizl*lun	0.16666666666666666
# Gizl*il	0.5
# Gizl*rin	0.16666666666666666
# Gizl*dir	0.16666666666666666
# Gizl*ti	0.2
# Gizl*'i	0.2
# Gizl*ri	0.2
# Gizl*sir	0.16666666666666666
# Gizl*sin	0.16666666666666666
# Gizl*mall	0.14285714285714285
# Gizl*Gizl	1.0
# Gizl*gi	0.2
# Gizl*gil	0.4
# Gizl*ul	0.2
# Gizl*hâl	0.16666666666666666
# Gizl*hind	0.14285714285714285
# Gizl*lar	0.16666666666666666
# Gizl*la	0.2
# Gizl*bi	0.2
# Gizl*di	0.2
# gi*bil	0.25
# gi*lind	0.2
# gi*ih	0.3333333333333333
# gi*hic	0.25
# gi*gor	0.25
# gi*yi	0.3333333333333333
# gi*i	0.5
# gi*gol	0.25
# gi*sind	0.2
# gi*pi	0.3333333333333333
# gi*din	0.25
# gi*il	0.3333333333333333
# gi*rin	0.25
# gi*dir	0.25
# gi*gund	0.2
# gi*ti	0.3333333333333333
# gi*'i	0.3333333333333333
# gi*ri	0.3333333333333333
# gi*sir	0.25
# gi*sin	0.25
# gi*Gizl	0.2
# gi*gi	1.0
# gi*gil	0.6666666666666666
# gi*hind	0.2
# gi*dug	0.25
# gi*gu	0.3333333333333333
# gi*Agus	0.2
# gi*bi	0.3333333333333333
# gi*di	0.3333333333333333
# Mo*kon	0.25
# Mo*gor	0.25
# Mo*ol	0.3333333333333333
# Mo*gol	0.25
# Mo*yok	0.25
# Mo*ko	0.3333333333333333
# Mo*to	0.3333333333333333
# Mo*Mo	1.0
# ka*kon	0.25
# ka*da	0.3333333333333333
# ka*Ta	0.3333333333333333
# ka*ya	0.3333333333333333
# ka*ta	0.3333333333333333
# ka*mak	0.6666666666666666
# ka*ma	0.3333333333333333
# ka*yok	0.25
# ka*Ha	0.3333333333333333
# ka*ko	0.3333333333333333
# ka*Han	0.25
# ka*Ya	0.3333333333333333
# ka*ke	0.3333333333333333
# ka*sap	0.25
# ka*mall	0.2
# ka*na	0.3333333333333333
# ka*ka	1.0
# ka*lar	0.25
# ka*la	0.3333333333333333
# gil*bil	0.5
# gil*lind	0.4
# gil*ih	0.25
# gil*hic	0.2
# gil*gor	0.2
# gil*yi	0.25
# gil*i	0.3333333333333333
# gil*ol	0.25
# gil*gol	0.5
# gil*sind	0.16666666666666666
# gil*pi	0.25
# gil*din	0.2
# gil*lun	0.2
# gil*il	0.6666666666666666
# gil*rin	0.2
# gil*dir	0.2
# gil*gund	0.16666666666666666
# gil*ti	0.25
# gil*'i	0.25
# gil*ri	0.25
# gil*sir	0.2
# gil*sin	0.2
# gil*mall	0.16666666666666666
# gil*Gizl	0.4
# gil*gi	0.6666666666666666
# gil*gil	1.0
# gil*ul	0.25
# gil*hâl	0.2
# gil*hind	0.16666666666666666
# gil*lar	0.2
# gil*dug	0.2
# gil*la	0.25
# gil*gu	0.25
# gil*Agus	0.16666666666666666
# gil*bi	0.25
# gil*di	0.25
# ul*bil	0.25
# ul*nus	0.25
# ul*lind	0.2
# ul*du	0.3333333333333333
# ul*muzd	0.2
# ul*ol	0.3333333333333333
# ul*gol	0.25
# ul*lun	0.6666666666666666
# ul*ru	0.3333333333333333
# ul*il	0.3333333333333333
# ul*gund	0.2
# ul*yu	0.3333333333333333
# ul*mall	0.2
# ul*bu	0.3333333333333333
# ul*Gizl	0.2
# ul*gil	0.25
# ul*ul	1.0
# ul*hâl	0.25
# ul*lar	0.25
# ul*dug	0.25
# ul*la	0.3333333333333333
# ul*gu	0.3333333333333333
# ul*nu	0.3333333333333333
# ul*Agus	0.2
# ul*tur	0.25
# hâl*bil	0.2
# hâl*lind	0.16666666666666666
# hâl*ih	0.25
# hâl*hic	0.2
# hâl*ol	0.25
# hâl*gol	0.2
# hâl*lun	0.2
# hâl*il	0.25
# hâl*he	0.25
# hâl*mall	0.16666666666666666
# hâl*Gizl	0.16666666666666666
# hâl*gil	0.2
# hâl*ul	0.25
# hâl*hâl	1.0
# hâl*hind	0.16666666666666666
# hâl*lar	0.2
# hâl*la	0.25
# b*bil	0.3333333333333333
# b*bu	0.5
# b*b	1.0
# b*bi	0.5
# hind*kon	0.16666666666666666
# hind*da	0.2
# hind*bil	0.16666666666666666
# hind*nus	0.16666666666666666
# hind*ne	0.2
# hind*den	0.4
# hind*lind	0.6
# hind*ih	0.5
# hind*hic	0.4
# hind*du	0.2
# hind*muzd	0.14285714285714285
# hind*yi	0.2
# hind*i	0.25
# hind*sind	0.6
# hind*red	0.16666666666666666
# hind*pi	0.2
# hind*din	0.75
# hind*lun	0.16666666666666666
# hind*il	0.2
# hind*rin	0.4
# hind*dir	0.4
# hind*he	0.2
# hind*gund	0.3333333333333333
# hind*Han	0.16666666666666666
# hind*ti	0.2
# hind*'i	0.2
# hind*ri	0.2
# hind*sir	0.16666666666666666
# hind*sin	0.4
# hind*n	0.25
# hind*na	0.2
# hind*Gizl	0.14285714285714285
# hind*gi	0.2
# hind*gil	0.16666666666666666
# hind*hâl	0.16666666666666666
# hind*hind	1.0
# hind*Cen	0.16666666666666666
# hind*dug	0.16666666666666666
# hind*nu	0.2
# hind*bi	0.2
# hind*di	0.5
# lar*da	0.25
# lar*bil	0.2
# lar*Ta	0.25
# lar*ya	0.25
# lar*lind	0.16666666666666666
# lar*ta	0.25
# lar*gor	0.2
# lar*ol	0.25
# lar*gol	0.2
# lar*red	0.2
# lar*mak	0.2
# lar*ma	0.25
# lar*lun	0.2
# lar*ru	0.25
# lar*il	0.25
# lar*rin	0.2
# lar*dir	0.2
# lar*Ha	0.25
# lar*Han	0.2
# lar*Ya	0.25
# lar*ri	0.25
# lar*sap	0.2
# lar*sir	0.2
# lar*mall	0.4
# lar*na	0.25
# lar*Gizl	0.16666666666666666
# lar*ka	0.25
# lar*gil	0.2
# lar*ul	0.25
# lar*hâl	0.2
# lar*lar	1.0
# lar*la	0.6666666666666666
# lar*tur	0.2
# Cen*kon	0.2
# Cen*se	0.25
# Cen*nus	0.2
# Cen*ne	0.6666666666666666
# Cen*den	0.5
# Cen*lind	0.16666666666666666
# Cen*sind	0.16666666666666666
# Cen*red	0.2
# Cen*din	0.2
# Cen*lun	0.2
# Cen*rin	0.2
# Cen*ce	0.25
# Cen*he	0.25
# Cen*gund	0.16666666666666666
# Cen*Han	0.2
# Cen*ke	0.25
# Cen*sin	0.2
# Cen*n	0.3333333333333333
# Cen*na	0.25
# Cen*hind	0.16666666666666666
# Cen*Cen	1.0
# Cen*nu	0.25
# dug*da	0.25
# dug*nus	0.2
# dug*den	0.2
# dug*lind	0.16666666666666666
# dug*gor	0.2
# dug*du	0.6666666666666666
# dug*muzd	0.4
# dug*gol	0.2
# dug*sind	0.16666666666666666
# dug*red	0.2
# dug*din	0.2
# dug*lun	0.2
# dug*ru	0.25
# dug*dir	0.2
# dug*gund	0.75
# dug*yu	0.25
# dug*bu	0.25
# dug*gi	0.25
# dug*gil	0.2
# dug*ul	0.25
# dug*hind	0.16666666666666666
# dug*dug	1.0
# dug*gu	0.6666666666666666
# dug*nu	0.25
# dug*Agus	0.4
# dug*tur	0.2
# dug*di	0.25
# la*da	0.3333333333333333
# la*bil	0.25
# la*Ta	0.3333333333333333
# la*ya	0.3333333333333333
# la*lind	0.2
# la*ta	0.3333333333333333
# la*ol	0.3333333333333333
# la*gol	0.25
# la*mak	0.25
# la*ma	0.3333333333333333
# la*lun	0.25
# la*il	0.3333333333333333
# la*Ha	0.3333333333333333
# la*Han	0.25
# la*Ya	0.3333333333333333
# la*sap	0.25
# la*mall	0.5
# la*na	0.3333333333333333
# la*Gizl	0.2
# la*ka	0.3333333333333333
# la*gil	0.25
# la*ul	0.3333333333333333
# la*hâl	0.25
# la*lar	0.6666666666666666
# la*la	1.0
# gu*nus	0.25
# gu*gor	0.25
# gu*du	0.3333333333333333
# gu*muzd	0.2
# gu*gol	0.25
# gu*lun	0.25
# gu*ru	0.3333333333333333
# gu*gund	0.5
# gu*yu	0.3333333333333333
# gu*bu	0.3333333333333333
# gu*gi	0.3333333333333333
# gu*gil	0.25
# gu*ul	0.3333333333333333
# gu*dug	0.6666666666666666
# gu*gu	1.0
# gu*nu	0.3333333333333333
# gu*Agus	0.5
# gu*tur	0.25
# nu*kon	0.25
# nu*nus	0.6666666666666666
# nu*ne	0.3333333333333333
# nu*den	0.25
# nu*lind	0.2
# nu*du	0.3333333333333333
# nu*muzd	0.2
# nu*sind	0.2
# nu*din	0.25
# nu*lun	0.6666666666666666
# nu*ru	0.3333333333333333
# nu*rin	0.25
# nu*gund	0.5
# nu*Han	0.25
# nu*yu	0.3333333333333333
# nu*sin	0.25
# nu*n	0.5
# nu*na	0.3333333333333333
# nu*bu	0.3333333333333333
# nu*ul	0.3333333333333333
# nu*hind	0.2
# nu*Cen	0.25
# nu*dug	0.25
# nu*gu	0.3333333333333333
# nu*nu	1.0
# nu*Agus	0.2
# nu*tur	0.25
# Agus*se	0.2
# Agus*nus	0.4
# Agus*gor	0.16666666666666666
# Agus*du	0.2
# Agus*muzd	0.14285714285714285
# Agus*gol	0.16666666666666666
# Agus*sind	0.14285714285714285
# Agus*lun	0.16666666666666666
# Agus*ru	0.2
# Agus*gund	0.3333333333333333
# Agus*yu	0.2
# Agus*sap	0.16666666666666666
# Agus*sir	0.16666666666666666
# Agus*sin	0.16666666666666666
# Agus*bu	0.2
# Agus*gi	0.2
# Agus*gil	0.16666666666666666
# Agus*ul	0.2
# Agus*dug	0.4
# Agus*gu	0.5
# Agus*nu	0.2
# Agus*Agus	1.0
# Agus*tur	0.16666666666666666
# tur*nus	0.2
# tur*ta	0.25
# tur*gor	0.2
# tur*du	0.25
# tur*muzd	0.16666666666666666
# tur*red	0.2
# tur*lun	0.2
# tur*ru	0.6666666666666666
# tur*rin	0.2
# tur*dir	0.2
# tur*gund	0.16666666666666666
# tur*yu	0.25
# tur*ti	0.25
# tur*ri	0.25
# tur*sir	0.2
# tur*to	0.25
# tur*bu	0.25
# tur*ul	0.25
# tur*lar	0.2
# tur*dug	0.2
# tur*gu	0.25
# tur*nu	0.25
# tur*Agus	0.16666666666666666
# tur*tur	1.0
# bi*bil	0.6666666666666666
# bi*lind	0.2
# bi*ih	0.3333333333333333
# bi*hic	0.25
# bi*yi	0.3333333333333333
# bi*i	0.5
# bi*sind	0.2
# bi*pi	0.3333333333333333
# bi*din	0.25
# bi*il	0.3333333333333333
# bi*rin	0.25
# bi*dir	0.25
# bi*ti	0.3333333333333333
# bi*'i	0.3333333333333333
# bi*ri	0.3333333333333333
# bi*sir	0.25
# bi*sin	0.25
# bi*bu	0.3333333333333333
# bi*Gizl	0.2
# bi*gi	0.3333333333333333
# bi*gil	0.25
# bi*b	0.5
# bi*hind	0.2
# bi*bi	1.0
# bi*di	0.3333333333333333
# di*da	0.3333333333333333
# di*bil	0.25
# di*den	0.25
# di*lind	0.5
# di*ih	0.3333333333333333
# di*hic	0.25
# di*du	0.3333333333333333
# di*muzd	0.2
# di*yi	0.3333333333333333
# di*i	0.5
# di*sind	0.5
# di*red	0.25
# di*pi	0.3333333333333333
# di*din	0.6666666666666666
# di*il	0.3333333333333333
# di*rin	0.25
# di*dir	0.6666666666666666
# di*gund	0.2
# di*ti	0.3333333333333333
# di*'i	0.3333333333333333
# di*ri	0.3333333333333333
# di*sir	0.25
# di*sin	0.25
# di*Gizl	0.2
# di*gi	0.3333333333333333
# di*gil	0.25
# di*hind	0.5
# di*dug	0.25
# di*bi	0.3333333333333333
# di*di	1.0
# ('122',)
# ('kon',)
# ('da',)
# ('bil',)
# ('se',)
# ('Ta',)
# ('nus',)
# ('ne',)
# ('den',)
# ('ya',)
# ('lind',)
# ('ih',)
# ('hic',)
# ('ta',)
# ('gor',)
# ('du',)
# ('muzd',)
# ('yi',)
# ('i',)
# ('ol',)
# ('gol',)
# ('sind',)
# ('red',)
# ('mak',)
# ('6',)
# ('ma',)
# ('pi',)
# ('din',)
# ('lun',)
# ('ru',)
# ('il',)
# ('rin',)
# ('dir',)
# ('ce',)
# ('yok',)
# ('Ha',)
# ('he',)
# ('gund',)
# ('ko',)
# ('Han',)
# ('2',)
# ('Ya',)
# ('ke',)
# ('yu',)
# ('ti',)
# ("'i",)
# ('ri',)
# ('sap',)
# ('sir',)
# ('sin',)
# ('mall',)
# ('n',)
# ('to',)
# ('na',)
# ('bu',)
# ('Gizl',)
# ('gi',)
# ('Mo',)
# ('ka',)
# ('gil',)
# ('ul',)
# ('hâl',)
# ('b',)
# ('hind',)
# ('lar',)
# ('Cen',)
# ('dug',)
# ('la',)
# ('gu',)
# ('nu',)
# ('Agus',)
# ('tur',)
# ('bi',)
# ('di',)
# ('122', 'kon')
# ('kon', 'da')
# ('da', 'bil')
# ('bil', 'se')
# ('se', 'Ta')
# ('Ta', 'nus')
# ('nus', 'ne')
# ('ne', 'den')
# ('den', 'ya')
# ('ya', 'lind')
# ('lind', 'ih')
# ('ih', 'hic')
# ('hic', 'ta')
# ('ta', 'gor')
# ('gor', 'du')
# ('du', 'muzd')
# ('muzd', 'yi')
# ('yi', 'i')
# ('i', 'ol')
# ('ol', 'gol')
# ('gol', 'sind')
# ('sind', 'red')
# ('red', 'mak')
# ('mak', '6')
# ('6', 'ma')
# ('ma', 'pi')
# ('pi', 'din')
# ('din', 'lun')
# ('lun', 'ru')
# ('ru', 'il')
# ('il', 'rin')
# ('rin', 'dir')
# ('dir', 'ce')
# ('ce', 'yok')
# ('yok', 'Ha')
# ('Ha', 'he')
# ('he', 'gund')
# ('gund', 'ko')
# ('ko', 'Han')
# ('Han', '2')
# ('2', 'Ya')
# ('Ya', 'ke')
# ('ke', 'yu')
# ('yu', 'ti')
# ('ti', "'i")
# ("'i", 'ri')
# ('ri', 'sap')
# ('sap', 'sir')
# ('sir', 'sin')
# ('sin', 'mall')
# ('mall', 'n')
# ('n', 'to')
# ('to', 'na')
# ('na', 'bu')
# ('bu', 'Gizl')
# ('Gizl', 'gi')
# ('gi', 'Mo')
# ('Mo', 'ka')
# ('ka', 'gil')
# ('gil', 'ul')
# ('ul', 'hâl')
# ('hâl', 'b')
# ('b', 'hind')
# ('hind', 'lar')
# ('lar', 'Cen')
# ('Cen', 'dug')
# ('dug', 'la')
# ('la', 'gu')
# ('gu', 'nu')
# ('nu', 'Agus')
# ('Agus', 'tur')
# ('tur', 'bi')
# ('bi', 'di')
# ('122', 'kon', 'da')
# ('kon', 'da', 'bil')
# ('da', 'bil', 'se')
# ('bil', 'se', 'Ta')
# ('se', 'Ta', 'nus')
# ('Ta', 'nus', 'ne')
# ('nus', 'ne', 'den')
# ('ne', 'den', 'ya')
# ('den', 'ya', 'lind')
# ('ya', 'lind', 'ih')
# ('lind', 'ih', 'hic')
# ('ih', 'hic', 'ta')
# ('hic', 'ta', 'gor')
# ('ta', 'gor', 'du')
# ('gor', 'du', 'muzd')
# ('du', 'muzd', 'yi')
# ('muzd', 'yi', 'i')
# ('yi', 'i', 'ol')
# ('i', 'ol', 'gol')
# ('ol', 'gol', 'sind')
# ('gol', 'sind', 'red')
# ('sind', 'red', 'mak')
# ('red', 'mak', '6')
# ('mak', '6', 'ma')
# ('6', 'ma', 'pi')
# ('ma', 'pi', 'din')
# ('pi', 'din', 'lun')
# ('din', 'lun', 'ru')
# ('lun', 'ru', 'il')
# ('ru', 'il', 'rin')
# ('il', 'rin', 'dir')
# ('rin', 'dir', 'ce')
# ('dir', 'ce', 'yok')
# ('ce', 'yok', 'Ha')
# ('yok', 'Ha', 'he')
# ('Ha', 'he', 'gund')
# ('he', 'gund', 'ko')
# ('gund', 'ko', 'Han')
# ('ko', 'Han', '2')
# ('Han', '2', 'Ya')
# ('2', 'Ya', 'ke')
# ('Ya', 'ke', 'yu')
# ('ke', 'yu', 'ti')
# ('yu', 'ti', "'i")
# ('ti', "'i", 'ri')
# ("'i", 'ri', 'sap')
# ('ri', 'sap', 'sir')
# ('sap', 'sir', 'sin')
# ('sir', 'sin', 'mall')
# ('sin', 'mall', 'n')
# ('mall', 'n', 'to')
# ('n', 'to', 'na')
# ('to', 'na', 'bu')
# ('na', 'bu', 'Gizl')
# ('bu', 'Gizl', 'gi')
# ('Gizl', 'gi', 'Mo')
# ('gi', 'Mo', 'ka')
# ('Mo', 'ka', 'gil')
# ('ka', 'gil', 'ul')
# ('gil', 'ul', 'hâl')
# ('ul', 'hâl', 'b')
# ('hâl', 'b', 'hind')
# ('b', 'hind', 'lar')
# ('hind', 'lar', 'Cen')
# ('lar', 'Cen', 'dug')
# ('Cen', 'dug', 'la')
# ('dug', 'la', 'gu')
# ('la', 'gu', 'nu')
# ('gu', 'nu', 'Agus')
# ('nu', 'Agus', 'tur')
# ('Agus', 'tur', 'bi')
# ('tur', 'bi', 'di')
